# %%
# !pip install fiftyone
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 5.7 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.1/135.1 kB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.5/564.5 kB 62.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 5.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 6.1 MB/s eta 0:00:00
# ...
#   Using cached PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 5.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 4.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 9.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...

# %%
import fiftyone as fo
import fiftyone.zoo as foz
# Out:
# Migrating database to v0.19.1

# %%
dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="test",
    label_types=["detections"],
    classes=["person"],
    max_samples=100,
    dataset_dir="../Datasets/fiftyone"
)
# Out:
# ...
# Test split is unlabeled; ignoring classes requirement
# ...
#  100% |██████|    8.7Mb/8.7Mb [747.7ms elapsed, 0s remaining, 11.7Mb/s]
# Extracting test info to '../Datasets/fiftyone/raw/image_info_test2017.json'
# ...
#  100% |██████████████████| 100/100 [5.8s elapsed, 0s remaining, 18.3 images/s]
# Writing annotations for 100 downloaded samples to '../Datasets/fiftyone/test/labels.json'
# Dataset info written to '../Datasets/fiftyone/info.json'
# Loading 'coco-2017' split 'test'
# Dataset is unlabeled; ignoring classes requirement
#  100% |█████████████████| 100/100 [67.6ms elapsed, 0s remaining, 1.5K samples/s]
# Dataset 'coco-2017-test-100' created
