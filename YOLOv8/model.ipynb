# %% [markdown]
# # YOLOv8 model

# %% [markdown]
# ## Analyzing and importing data
#
# Dataset we're using is already split into train, test and validation sets.

# %%
import random
from pylab import rcParams

import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
train_dir = "../../Datasets/Human.v2i.yolov8/train"
test_dir = "../../Datasets/Human.v2i.yolov8/test"
val_dir = "../../Datasets/Human.v2i.yolov8/test"

# %%
import random

rcParams['figure.figsize'] = 10, 10

for i in range(5):
    file = random.choice(os.listdir( os.path.join(train_dir + "/images")))
    image_path= os.path.join(os.path.join(train_dir + "/images"), file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    plt.imshow(img)
